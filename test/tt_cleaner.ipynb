# %%
import pandas

# %%
df=pandas.read_excel(
    './6th_Divsion_TT.xlsx', sheet_name='6B4_AI'
)
df.head(15)
# Out:
#    Unnamed: 0                 Unnamed: 1             Unnamed: 2  \
# 0         NaN                        NaN                    NaN
# 1         NaN                        NaN                    NaN
# 2         NaN                        NaN                    NaN
# 3         NaN                        NaN                    NaN
# 4    Sr.\nNo.  DAY\nTIMING                      MONDAY (online)
# 5           1              10:00 - 11:00              6B4:CS:F1
# 6           2              11:00 - 12:00              6B4:CS:F1
# 7         NaN              12:00 - 01:00                 RECESS
# 8           3              01:00 - 01:50             6B4:MAD:F1
# 9           4               01:50  02:40                LIBRARY
# 10        NaN              02:40 - 03:00                 RECESS
# 11          5              03:00 - 04:00  6B41:CS:F1 6B42:CS:F1
# 12          6              04:00 - 05:00                    NaN
# 13        NaN                        NaN                    NaN
# ...

# %%
shape=df.shape
shape
# Out:
# (33, 10)

# %%
drop_these=[]
for i in range(0,shape[0]):
    if(i>3 and i<13):
        continue
    drop_these.append(i)
df=df.drop(drop_these)
df = df.drop(columns=["Unnamed: 0", "Unnamed: 7",
             "Unnamed: 8", "Unnamed: 9"], axis=1)
df
# Out:
#                    Unnamed: 1             Unnamed: 2  \
# 4   DAY\nTIMING                      MONDAY (online)
# 5               10:00 - 11:00              6B4:CS:F1
# 6               11:00 - 12:00              6B4:CS:F1
# 7               12:00 - 01:00                 RECESS
# 8               01:00 - 01:50             6B4:MAD:F1
# 9                01:50  02:40                LIBRARY
# 10              02:40 - 03:00                 RECESS
# 11              03:00 - 04:00  6B41:CS:F1 6B42:CS:F1
# 12              04:00 - 05:00                    NaN
#
#    FACULTY OF ENGINEERING & TECHNOLOGY         Unnamed: 4  \
# 4                              TUESDAY          WEDNESDAY
# 5                    6B4:GPU:MK(N-608)   6B4:ML:TM1:N-607
# 6                    6B4:GPU:MK(N-608)   6B4:CD:SK(N-607)
# 7                                  NaN                NaN
# 8                      6B4:ES: (N-608)            LIBRARY
# 9                     6B4:CD:SK(N-608)                NaN
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#                   Unnamed: 1             Unnamed: 2  \
# 0  DAY\nTIMING                      MONDAY (online)
# 1              10:00 - 11:00              6B4:CS:F1
# 2              11:00 - 12:00              6B4:CS:F1
# 3              12:00 - 01:00                 RECESS
# 4              01:00 - 01:50             6B4:MAD:F1
# 5               01:50  02:40                LIBRARY
# 6              02:40 - 03:00                 RECESS
# 7              03:00 - 04:00  6B41:CS:F1 6B42:CS:F1
# 8              04:00 - 05:00                    NaN
#
#   FACULTY OF ENGINEERING & TECHNOLOGY         Unnamed: 4  \
# 0                             TUESDAY          WEDNESDAY
# 1                   6B4:GPU:MK(N-608)   6B4:ML:TM1:N-607
# 2                   6B4:GPU:MK(N-608)   6B4:CD:SK(N-607)
# 3                                 NaN                NaN
# 4                     6B4:ES: (N-608)            LIBRARY
# 5                    6B4:CD:SK(N-608)                NaN
# ...

# %%
cols = df.iloc[0, :]
df.columns = cols

# %%
df
# Out:
# 0  DAY\nTIMING                      MONDAY (online)            TUESDAY  \
# 0  DAY\nTIMING                      MONDAY (online)            TUESDAY
# 1              10:00 - 11:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 2              11:00 - 12:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 3              12:00 - 01:00                 RECESS                NaN
# 4              01:00 - 01:50             6B4:MAD:F1    6B4:ES: (N-608)
# 5               01:50  02:40                LIBRARY   6B4:CD:SK(N-608)
# 6              02:40 - 03:00                 RECESS                NaN
# 7              03:00 - 04:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
# 8              04:00 - 05:00                    NaN    6B4:ML:AR:N-608
#
# 0          WEDNESDAY                      THURSDAY  \
# 0          WEDNESDAY                      THURSDAY
# 1   6B4:ML:TM1:N-607                    6B4:MAD:BM
# 2   6B4:CD:SK(N-607)                    6B4:MAD:BM
# ...

# %%
df=df.drop(0)
df
# Out:
# 0 DAY\nTIMING                      MONDAY (online)            TUESDAY  \
# 1             10:00 - 11:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 2             11:00 - 12:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 3             12:00 - 01:00                 RECESS                NaN
# 4             01:00 - 01:50             6B4:MAD:F1    6B4:ES: (N-608)
# 5              01:50  02:40                LIBRARY   6B4:CD:SK(N-608)
# 6             02:40 - 03:00                 RECESS                NaN
# 7             03:00 - 04:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
# 8             04:00 - 05:00                    NaN    6B4:ML:AR:N-608
#
# 0          WEDNESDAY                      THURSDAY  \
# 1   6B4:ML:TM1:N-607                    6B4:MAD:BM
# 2   6B4:CD:SK(N-607)                    6B4:MAD:BM
# 3                NaN                           NaN
# 4            LIBRARY                     6B4:CS:F1
# 5                NaN                       LIBRARY
# ...

# %%
df=df.reset_index()

# %%
df=df.drop(columns='index')
df
# Out:
# 0 DAY\nTIMING                      MONDAY (online)            TUESDAY  \
# 0             10:00 - 11:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 1             11:00 - 12:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 2             12:00 - 01:00                 RECESS                NaN
# 3             01:00 - 01:50             6B4:MAD:F1    6B4:ES: (N-608)
# 4              01:50  02:40                LIBRARY   6B4:CD:SK(N-608)
# 5             02:40 - 03:00                 RECESS                NaN
# 6             03:00 - 04:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
# 7             04:00 - 05:00                    NaN    6B4:ML:AR:N-608
#
# 0          WEDNESDAY                      THURSDAY  \
# 0   6B4:ML:TM1:N-607                    6B4:MAD:BM
# 1   6B4:CD:SK(N-607)                    6B4:MAD:BM
# 2                NaN                           NaN
# 3            LIBRARY                     6B4:CS:F1
# 4                NaN                       LIBRARY
# ...

# %%
df.iloc[2, :] = df.iloc[2, :].fillna('RECESS')
df.iloc[5, :] = df.iloc[5, :].fillna('RECESS')

# %%
df
# Out:
# 0 DAY\nTIMING                      MONDAY (online)            TUESDAY  \
# 0             10:00 - 11:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 1             11:00 - 12:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 2             12:00 - 01:00                 RECESS             RECESS
# 3             01:00 - 01:50             6B4:MAD:F1    6B4:ES: (N-608)
# 4              01:50  02:40                LIBRARY   6B4:CD:SK(N-608)
# 5             02:40 - 03:00                 RECESS             RECESS
# 6             03:00 - 04:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
# 7             04:00 - 05:00                    NaN    6B4:ML:AR:N-608
#
# 0          WEDNESDAY                      THURSDAY  \
# 0   6B4:ML:TM1:N-607                    6B4:MAD:BM
# 1   6B4:CD:SK(N-607)                    6B4:MAD:BM
# 2             RECESS                        RECESS
# 3            LIBRARY                     6B4:CS:F1
# 4                NaN                       LIBRARY
# ...

# %%
df.iloc[4,0]='01:50 - 02:40'

# %%
df
# Out:
# 0 DAY\nTIMING                      MONDAY (online)            TUESDAY  \
# 0             10:00 - 11:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 1             11:00 - 12:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 2             12:00 - 01:00                 RECESS             RECESS
# 3             01:00 - 01:50             6B4:MAD:F1    6B4:ES: (N-608)
# 4             01:50 - 02:40                LIBRARY   6B4:CD:SK(N-608)
# 5             02:40 - 03:00                 RECESS             RECESS
# 6             03:00 - 04:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
# 7             04:00 - 05:00                    NaN    6B4:ML:AR:N-608
#
# 0          WEDNESDAY                      THURSDAY  \
# 0   6B4:ML:TM1:N-607                    6B4:MAD:BM
# 1   6B4:CD:SK(N-607)                    6B4:MAD:BM
# 2             RECESS                        RECESS
# 3            LIBRARY                     6B4:CS:F1
# 4                NaN                       LIBRARY
# ...

# %%
# filling values that are above them
# shape=list(df.shape)
# if (df.iloc[i, j] == float("nan")):
#     df.iloc[i, j] = df[i-1, j]
# df.iloc[:,:].fillna(df.iloc[,:])
# type(shape)
# theres an inbuilt function noob:
df.fillna(method='ffill', inplace=True)

# %% [markdown]
# # Final Output:

# %%
df
# Out:
# 0 DAY\nTIMING                      MONDAY (online)            TUESDAY  \
# 0             10:00 - 11:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 1             11:00 - 12:00              6B4:CS:F1  6B4:GPU:MK(N-608)
# 2             12:00 - 01:00                 RECESS             RECESS
# 3             01:00 - 01:50             6B4:MAD:F1    6B4:ES: (N-608)
# 4             01:50 - 02:40                LIBRARY   6B4:CD:SK(N-608)
# 5             02:40 - 03:00                 RECESS             RECESS
# 6             03:00 - 04:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
# 7             04:00 - 05:00  6B41:CS:F1 6B42:CS:F1    6B4:ML:AR:N-608
#
# 0          WEDNESDAY                      THURSDAY  \
# 0   6B4:ML:TM1:N-607                    6B4:MAD:BM
# 1   6B4:CD:SK(N-607)                    6B4:MAD:BM
# 2             RECESS                        RECESS
# 3            LIBRARY                     6B4:CS:F1
# 4            LIBRARY                       LIBRARY
# ...

# %%
# in any col,row; if there is a 'RECESS'; fill the entire row with that RECESS value

# recess_columns=df[df.iloc[:,:]=='RECESS']
# for i in recess_columns.iloc[i,]:
#     if(i==''
        
#     ):
#         recess_columns.drop(i)

# %% [markdown]
# # Test:

# %%
dff=pandas.read_excel('./6th_Divsion_TT.xlsx')

# %%
df1 = pandas.read_excel(
    './6th_Divsion_TT.xlsx', sheet_name='6B5_AI'
)
df1.head(15)
# Out:
#    Unnamed: 0                 Unnamed: 1                 Unnamed: 2  \
# 0         NaN                        NaN                        NaN
# 1         NaN                        NaN                        NaN
# 2         NaN                        NaN                        NaN
# 3         NaN                        NaN                        NaN
# 4    Sr.\nNo.  DAY\nTIMING                                  MONDAY
# 5           1              10:00 - 11:00            6B5:ML:AR:N-604
# 6           2              11:00 - 12:00            6B5:ML:AR:N-604
# 7         NaN              12:00 - 01:00                     RECESS
# 8           3              01:00 - 01:50          6B5:CD:BRD(N-604)
# 9           4               01:50  02:40        6B5:GPU:MK:(N -604)
# 10        NaN              02:40 - 03:00                     RECESS
# 11          5              03:00 - 04:00  6B5:ML:AR:N-604/ LIBRARY/
# 12          6              04:00 - 05:00                        NaN
# ...

# %%
df1=df1.drop(columns=["Unnamed: 0", "Unnamed: 7",
                  "Unnamed: 8", "Unnamed: 9"], )
df1
# Out:
#                    Unnamed: 1                                 Unnamed: 2  \
# 0                         NaN                                        NaN
# 1                         NaN                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4   DAY\nTIMING                                                  MONDAY
# 5               10:00 - 11:00                            6B5:ML:AR:N-604
# 6               11:00 - 12:00                            6B5:ML:AR:N-604
# 7               12:00 - 01:00                                     RECESS
# 8               01:00 - 01:50                          6B5:CD:BRD(N-604)
# 9                01:50  02:40                        6B5:GPU:MK:(N -604)
# 10              02:40 - 03:00                                     RECESS
# 11              03:00 - 04:00                  6B5:ML:AR:N-604/ LIBRARY/
# ...

# %%
drop_these=[]
for i in range(0,shape[0]):
    if(i>3 and i<13):
        continue
    drop_these.append(i)
df1=df1.drop(drop_these)
df1
# Out:
#                    Unnamed: 1                 Unnamed: 2  \
# 4   DAY\nTIMING                                  MONDAY
# 5               10:00 - 11:00            6B5:ML:AR:N-604
# 6               11:00 - 12:00            6B5:ML:AR:N-604
# 7               12:00 - 01:00                     RECESS
# 8               01:00 - 01:50          6B5:CD:BRD(N-604)
# 9                01:50  02:40        6B5:GPU:MK:(N -604)
# 10              02:40 - 03:00                     RECESS
# 11              03:00 - 04:00  6B5:ML:AR:N-604/ LIBRARY/
# 12              04:00 - 05:00                        NaN
#
#      FACULTY OF ENGINEERING & TECHNOLOGY                    Unnamed: 4  \
# 4                        TUESDAY(online)             WEDNESDAY(online)
# 5                              6B5:CS:F1                    6B5:MAD:F1
# 6                              6B5:CS:F1                    6B5:MAD:F1
# 7                                    NaN                           NaN
# ...

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#                   Unnamed: 1                 Unnamed: 2  \
# 0  DAY\nTIMING                                  MONDAY
# 1              10:00 - 11:00            6B5:ML:AR:N-604
# 2              11:00 - 12:00            6B5:ML:AR:N-604
# 3              12:00 - 01:00                     RECESS
# 4              01:00 - 01:50          6B5:CD:BRD(N-604)
# 5               01:50  02:40        6B5:GPU:MK:(N -604)
# 6              02:40 - 03:00                     RECESS
# 7              03:00 - 04:00  6B5:ML:AR:N-604/ LIBRARY/
# 8              04:00 - 05:00                        NaN
#
#     FACULTY OF ENGINEERING & TECHNOLOGY                    Unnamed: 4  \
# 0                       TUESDAY(online)             WEDNESDAY(online)
# 1                             6B5:CS:F1                    6B5:MAD:F1
# 2                             6B5:CS:F1                    6B5:MAD:F1
# 3                                   NaN                           NaN
# ...

# %%
cols = df1.iloc[0, :]
df1.columns = cols
df1=df1.drop(0)
# df1.iloc[0, 1:]
df1
# Out:
# 0 DAY\nTIMING                                  MONDAY   \
# 1             10:00 - 11:00            6B5:ML:AR:N-604
# 2             11:00 - 12:00            6B5:ML:AR:N-604
# 3             12:00 - 01:00                     RECESS
# 4             01:00 - 01:50          6B5:CD:BRD(N-604)
# 5              01:50  02:40        6B5:GPU:MK:(N -604)
# 6             02:40 - 03:00                     RECESS
# 7             03:00 - 04:00  6B5:ML:AR:N-604/ LIBRARY/
# 8             04:00 - 05:00                        NaN
#
# 0                       TUESDAY(online)             WEDNESDAY(online)  \
# 1                             6B5:CS:F1                    6B5:MAD:F1
# 2                             6B5:CS:F1                    6B5:MAD:F1
# 3                                   NaN                           NaN
# 4                            6B5:MAD:BM                     6B5:CS:F1
# 5                               LIBRARY                       LIBRARY
# ...

# %%
df1=df1.reset_index()
df1 = df1.drop(columns='index')
# df1=df1.drop(0)
df1
# Out:
# 0 DAY\nTIMING                                  MONDAY   \
# 0             10:00 - 11:00            6B5:ML:AR:N-604
# 1             11:00 - 12:00            6B5:ML:AR:N-604
# 2             12:00 - 01:00                     RECESS
# 3             01:00 - 01:50          6B5:CD:BRD(N-604)
# 4              01:50  02:40        6B5:GPU:MK:(N -604)
# 5             02:40 - 03:00                     RECESS
# 6             03:00 - 04:00  6B5:ML:AR:N-604/ LIBRARY/
# 7             04:00 - 05:00                        NaN
#
# 0                       TUESDAY(online)             WEDNESDAY(online)  \
# 0                             6B5:CS:F1                    6B5:MAD:F1
# 1                             6B5:CS:F1                    6B5:MAD:F1
# 2                                   NaN                           NaN
# 3                            6B5:MAD:BM                     6B5:CS:F1
# 4                               LIBRARY                       LIBRARY
# ...

# %%
df1.iloc[2, :] = df1.iloc[2, :].fillna('RECESS')
df1.iloc[5, :] = df1.iloc[5, :].fillna('RECESS')
df1
# Out:
# 0 DAY\nTIMING                                  MONDAY   \
# 0             10:00 - 11:00            6B5:ML:AR:N-604
# 1             11:00 - 12:00            6B5:ML:AR:N-604
# 2             12:00 - 01:00                     RECESS
# 3             01:00 - 01:50          6B5:CD:BRD(N-604)
# 4              01:50  02:40        6B5:GPU:MK:(N -604)
# 5             02:40 - 03:00                     RECESS
# 6             03:00 - 04:00  6B5:ML:AR:N-604/ LIBRARY/
# 7             04:00 - 05:00                        NaN
#
# 0                       TUESDAY(online)             WEDNESDAY(online)  \
# 0                             6B5:CS:F1                    6B5:MAD:F1
# 1                             6B5:CS:F1                    6B5:MAD:F1
# 2                                RECESS                        RECESS
# 3                            6B5:MAD:BM                     6B5:CS:F1
# 4                               LIBRARY                       LIBRARY
# ...
